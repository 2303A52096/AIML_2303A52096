# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52096/AIML_2303A52096/blob/main/AIML_LAB01(part3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# susPart 3 Access Data from Various Data Sources using builtin Func- tion of Numpy, Pandas [CO3]
# 1. Generate your own dataset using MS Excel and Notepad to prepare the dataset. Save it in Google Drive and access it in Google Colab.
# 2. Upload the text file using tab seperated value(.tsv) and access the data from the file.
# 3. Upload the text file using comma seperated value(.csv) and access the data from file.
# 4. Access the excel file using .xlsx
# 5. Access the text from the URL

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/drive/MyDrive/aiml/hello my name is sathwika.txt")

# %%
df1
# Out:
#   hello my name is sathwika
# 0             google collab
# 1                      aiml

# %%
data3 = pd.read_excel("/content/drive/MyDrive/aiml/Book1.xlsx")

# %%
data3
# Out:
#             name  Unnamed: 1 roll number  Unnamed: 3 branch   specialization  \
# 0     k.sathwika         NaN  2303A52096         NaN    CSE             aiml
# 1    p.sushanthi         NaN  2303A52102         NaN    CSE     data science
# 2   r.soumya sri         NaN  2303A52105         NaN    CSE    cybersecurity
# 3     s.vyshnavi         NaN  2303A52107         NaN  civil              NaN
# 4     p.kanchana         NaN  2303A32345         NaN    ECE              NaN
# 5         murari         NaN  2303A54361         NaN    EEE              NaN
# 6        prabhas         NaN  2303A51301         NaN    CSE             aiml
# 7         charan         NaN  2303A52095         NaN    CSE    cybersecurity
# 8         deepak         NaN  2303A52097         NaN    ECE             aiml
# 9         dinesh         NaN  2303A52098         NaN    ECE             aiml
# 10       aradhya         NaN  2303A51234         NaN  CIVIL              iot
# ...

# %%
data2 = pd.read_csv("/content/drive/MyDrive/aiml/color_srgb.csv")

# %%
data2
# Out:
#        Name      HEX               RGB
# 0     White  #FFFFFF  rgb(100,100,100)
# 1    Silver  #C0C0C0     rgb(75,75,75)
# 2      Gray  #808080     rgb(50,50,50)
# 3     Black  #000000        rgb(0,0,0)
# 4       Red  #FF0000      rgb(100,0,0)
# 5    Maroon  #800000       rgb(50,0,0)
# 6    Yellow  #FFFF00    rgb(100,100,0)
# 7     Olive  #808000      rgb(50,50,0)
# 8      Lime  #00FF00      rgb(0,100,0)
# 9     Green  #008000       rgb(0,50,0)
# 10     Aqua  #00FFFF    rgb(0,100,100)
# 11     Teal  #008080      rgb(0,50,50)
# 12     Blue  #0000FF      rgb(0,0,100)
# 13     Navy  #000080       rgb(0,0,50)
# 14  Fuchsia  #FF00FF    rgb(100,0,100)
# 15   Purple  #800080      rgb(50,0,50)
